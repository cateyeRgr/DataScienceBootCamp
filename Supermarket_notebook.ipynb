# %% [markdown]
# # Final Project
#
# Welcome to the final practical project for our course on [Data Science Bootcamp](https://open.hpi.de/courses/datascience2023). Throughout this project, you will go through the entire data science process, starting from data loading and cleaning, all the way to running a model and making predictions. This hands-on project will provide you with valuable experience and allow you to apply the concepts and techniques you've learned in the course. Get ready to dive into real-world data analysis and build your skills as a data scientist!
#
#
# ## Important Remarks:
#
#  - The ultimate goal of this project is to conduct comprehensive data analysis and build 2 models using the provided datasets.
#  - Code is not the only thing graded here. Well-written and understandable documentation of your code is to be expected
#  - Clear reasoning behind your choices in every step of the notebook is important. Be it the choice of a data cleaning technique or selecting certain features in your analysis or the choice of your 2 models.

# %% [markdown]
# # Importing packages

# %%
#Import Pandas library + Matplotlib for graphics
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the dataset into data

# %%
#Read data
supermarket = pd.read_csv("supermarket_survey.csv")

# %% [markdown]
# # Dataset overview and statistical summary

# %%
# Display the head of the dataset
supermarket.head()
# Out:
#   randomInt;age;gender;district;modeOfTransportation;distance;G03Q13amountOfPeople;income;frequency;days[1];days[2];days[3];days[4];days[5];days[6];days[7];time[1];time[2];time[3];time[4];time[5];moneySpent;orderingItems;deliveringItems;willingPayDelivery;findProducts;usingDiscounts;preferCash;preferCashless;isRelaxing;satisGeneralStore;satisMusic;satisQualityProducts;satisGeneralAssortment;satisVeganProducts;satisOrganicProducts;satisGlutenfreeProducts;satisAnimalProducts;ideasExtendedBusiness;ideasHelpCarry;ideasCustomerCouncil;ideasFreeWifi;ideasTouchDisplay;ideasSelfCheckout;ideasBikeParking;ideasUndergroundParking
# 0  4;;Male;Godham;Own Car;1-2km;3;120000;Twice;No...
# 1  4;;;;;;;;;No;No;No;No;No;No;No;No;No;No;No;No;...
# 2  3;20-25;Female;Springtown;Own Car;>7km;2;15;Th...
# 3  4;;;;;;;1337;;No;No;No;No;No;No;No;No;No;No;No...
# 4  3;15-20;Male;Piltunder;Own Car;1-2km;4;250000;...

# %%
supermarket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Non-Null Count  Dtype
# ...

# %%
supermarket.describe()
# Out:
#        randomInt;age;gender;district;modeOfTransportation;distance;G03Q13amountOfPeople;income;frequency;days[1];days[2];days[3];days[4];days[5];days[6];days[7];time[1];time[2];time[3];time[4];time[5];moneySpent;orderingItems;deliveringItems;willingPayDelivery;findProducts;usingDiscounts;preferCash;preferCashless;isRelaxing;satisGeneralStore;satisMusic;satisQualityProducts;satisGeneralAssortment;satisVeganProducts;satisOrganicProducts;satisGlutenfreeProducts;satisAnimalProducts;ideasExtendedBusiness;ideasHelpCarry;ideasCustomerCouncil;ideasFreeWifi;ideasTouchDisplay;ideasSelfCheckout;ideasBikeParking;ideasUndergroundParking
# count                                                 353
# unique                                                352
# top     1;;;;;;;;;No;No;No;No;No;No;No;No;No;No;No;No;...
# freq                                                    2

# %% [markdown]
# # Data cleaning

# %%
# str.split() function: We’ll append the str.split() function to the name of the original column and define the separator 
# as a semicolon, then we’ll assign the output of the result to a new column called models_list.

supermarket['index_list'] = supermarket.iloc[:,0].str.split(';')

# %%
supermarket.head()
# Out:
#   randomInt;age;gender;district;modeOfTransportation;distance;G03Q13amountOfPeople;income;frequency;days[1];days[2];days[3];days[4];days[5];days[6];days[7];time[1];time[2];time[3];time[4];time[5];moneySpent;orderingItems;deliveringItems;willingPayDelivery;findProducts;usingDiscounts;preferCash;preferCashless;isRelaxing;satisGeneralStore;satisMusic;satisQualityProducts;satisGeneralAssortment;satisVeganProducts;satisOrganicProducts;satisGlutenfreeProducts;satisAnimalProducts;ideasExtendedBusiness;ideasHelpCarry;ideasCustomerCouncil;ideasFreeWifi;ideasTouchDisplay;ideasSelfCheckout;ideasBikeParking;ideasUndergroundParking  \
# 0  4;;Male;Godham;Own Car;1-2km;3;120000;Twice;No...
# 1  4;;;;;;;;;No;No;No;No;No;No;No;No;No;No;No;No;...
# 2  3;20-25;Female;Springtown;Own Car;>7km;2;15;Th...
# 3  4;;;;;;;1337;;No;No;No;No;No;No;No;No;No;No;No...
# 4  3;15-20;Male;Piltunder;Own Car;1-2km;4;250000;...
#
#                                          models_list model_0 model_1 model_2  \
# ...

# %%
# We can take each of these list values and store them in their own Pandas column. Our lists are of unequal length, which makes this trickier. 
# We’ll first create a new dataframe called df_models and will use tolist() to pass in the data from models_list. 
# This returns a Pandas dataframe with each of the list values in their own column. We’ll then use fillna('') to replace any NaN values with 
# an empty string and prefix each column with model_.
df_index = pd.DataFrame(supermarket['index_list'].tolist()).fillna('').add_prefix('index_')

# %%
#supermarket = pd.concat([supermarket, df_models], axis=1)
df_index.head()

#erase columns for heatmap
df_index = df_index.drop(df_index.columns[[10,n]], axis=1) 


#find/ calculate missing values
# sex, district, Mode of Transportation... -> categorial values -> mode
df_index.mode

#amount of people, frequency, days, satisfaction... -> ordinal values -> median
df_index.median

#fill in mode and median where necessary 
#e.g.

df_index["index_1"].fillna("20-25")
df_index["index_3"].fillna("Male")
df_index["index_4"].fillna("Godham")
df_index["index_5"].fillna("Own Car")
df_index["index_6"].fillna("1-2km")
df_index["index_7"].fillna("3")
df_index["index_8"].fillna("Twice")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_185/3331367357.py in <module>
#       3
#       4 #erase columns for heatmap
# ----> 5 df_index = df_index.drop(df_index.columns[[10,n]], axis=1)
#       6
#       7
#
# NameError: name 'n' is not defined

# %% [markdown]
# # EDA

# %%
#import seaborn for visualization
import seaborn as sns

# %%
sns.pairplot(df_index, x_vars= ['index_1','index_2','index_3', 'index_4'], y_vars=['index_1','index_2','index_3', 'index_4'])

# %%
#Correlation matrix for supermarket dataset
plt.figure(figsize=(4,4),dpi=50)
plt.title('Correlation matrix for supermarket dataset');
result=df_index.corr()
sns.heatmap(result, annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_185/2103307096.py in <module>
#       3 plt.title('Correlation matrix for supermarket dataset');
#       4 result=df_index.corr()
# ----> 5 sns.heatmap(result, annot=True)
#
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/conda/lib/python3.9/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     538     """
#     539     # Initialize the plotter object
# ...

# %% [markdown]
# # Data Processing and normalization

# %% [markdown]
# # Creating ML model 1

# %%
# Import necessary libraries
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
import pandas as pd

# %%
# Create X,y from dataset. 
# -> Find out if there's a relationship between distance and income   

df = pd.DataFrame(data=df_index)
#convert columns into series for reshaping
#Unfortunately, I used deprecated methods .ix -> doesn't work in this version of jupyter
serDistance = df.ix[:,6]
serIncome = serAge = df.ix[:,8]

X = serDistance.reshape(1,-1)
y = serIncome.reshape(1,-1)

#Create Linear Regression Object
model=LinearRegression()

# %%
#Fit the model 
model.fit(X,y)

# %% [markdown]
# ## Prediction on Test data

# %% [markdown]
# ## Model 1 Performance

# %%
# Print the accuracy score of the classifier
print(f"Accuracy using score function: {model.score(X, y)*100}%")

# %% [markdown]
# # Creating ML model 2

# %%
#DecisionTree:  

from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.metrics import mean_absolute_error

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(diabetes.data, diabetes.target, test_size=0.2, random_state=42)

# Create a decision tree regressor with a maximum depth of 3
DTR = DecisionTreeRegressor(max_depth=5)

# Train the regressor on the training set
DTR.fit(X_train, y_train)

# %%
# Do the split with 75% train and 25% test. replace the string with the actual input
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.3,
                                                    stratify=y,  # Leave this unchanged 
                                                    random_state=42) # Leave this unchanged
# Create a decision tree classifier with a maximum depth of 3
DTC = DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# ## Prediction on Test data

# %%
# Predict the target values for the testing set
y_pred = DTR.predict(X_test)

# %% [markdown]
# ## ## Model 2 Performance

# %%
# Print the mean squared error of the regressor
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test, y_pred))

# %% [markdown]
# # Report and insight from your analysis
